# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data=pd.read_csv("voltageData.csv")
data.tail()
# Out:
#     Exc-wall dist (cm)  Tag-wall dist (cm)  \
# 67               237.7               101.5
# 68               237.7               102.5
# 69               237.7               103.5
# 70               237.7               104.5
# 71               237.7               105.5
#
#                                      Tag Voltage (mV)
# 67  [136.38 136.61 135.77 136.3  135.92 136.07 136...
# 68  [192.38 192.3  191.77 192.23 192.45 191.62 192...
# 69  [252.5  252.19 251.74 251.58 252.19 252.65 252...
# 70  [295.45 293.77 293.39 294.08 293.39 294.92 294...
# 71  [328.79 329.71 329.63 328.79 330.01 330.55 328...

# %%
tag_wall_dist=data["Tag-wall dist (cm)"].to_numpy()
Y=[np.median(list(map(float, y.replace('[','').replace(']','').split()))) for y in data["Tag Voltage (mV)"]]

# %%
plt.plot(tag_wall_dist,Y,'.')
